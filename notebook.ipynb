# %%
import importlib
import inference

# %%
importlib.reload(inference)
# Out:
# <module 'inference' from 'd:\\code\\tensorflow\\inference.py'>

# %%
predict_sms(
    "Congratulations! You have won a free prize."
)
# Out:
# {'prediction': 'spam',
#  'ham_probability': 0.0012225593673065305,
#  'spam_probability': 0.998777449131012}

# %%
predict_sms(
    "Are we still meeting at 6 today?"
)
# Out:
# {'prediction': 'ham',
#  'ham_probability': 0.9992239475250244,
#  'spam_probability': 0.0007760215667076409}

# %%
predict_sms(
    "Hey, it’s Rahul. I’m using a temporary number because my phone is being repaired. I just sent a login code to your phone by mistake—can you forward the six digits?"
)
# social engineering attempt, spam, it fails to detect it as spam because the model is not trained on social engineering attempts
# Out:
# {'prediction': 'ham',
#  'ham_probability': 0.6436412334442139,
#  'spam_probability': 0.35635873675346375}
